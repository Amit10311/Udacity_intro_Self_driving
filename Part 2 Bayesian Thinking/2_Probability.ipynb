# %% [markdown]
# # **2.1 Uncertainty in Driving**

# %% [markdown]
# Using the word **certain** the way we'll use it in this Nanodegree, nothing in the previous question is ever certain. Let me explain.
#
#  1. **What other traffic will do :** People are impossible to predict with certainty!
#
#  2. **Where you are:** It may seem like you know where you are when you drive, but you don't. At least not with complete certainty. You may know where you are with sufficient certainty, but if I asked you how many millimeters away from the center lane you were, you wouldn't know.
#
#  3. **How fast you're going:** The same reasoning applies to knowing your speed. You can get a good idea of how fast you're going by looking at your speedometer (which measures your speed), but these measurements are never perfect.
#
#  4. **What will happen when you turn the wheel:** A car is an imperfect mechanical system. If you turned the steering wheel by the same amount 100 times, the car would turn a slightly different amount every time.

# %% [markdown]
# As humans we solve these problems in a variety of ways.
#  * Number 2 and 3 we solve by saying "ehh, I actually don't need to know exactly where I am or how fast I'm going, I just need to know those quantities with a high degree of certainty".
#  *  Number 4 we solve by using our brain as a high performance adaptive controller.
#  * And number 1... who knows how we handle number 1...? (just kidding, you'll learn more about this in the machine learning course at the end of this curriculum).

# %% [markdown]
# ## `QUIZ QUESTION`
# When a self driving car drives down the road, which of the following quantities is it ever possible for the car to know **with certainty**?

# %% [markdown]
# * Not Speed
# * Not it's Motion
# * Not it's Position
# * **We can drive safely with uncertainuty vatiables of system and near by environment.**

# %% [markdown]
# * Everything listed here is only "knowable" in a probabilistic sense. Luckily we don't need **complete certainty** to make a self driving car drive safely and efficiently.
#  * **In fact, humans drive (reasonably) safely with imperfect knowledge all the time!**

# %% [markdown]
# **Why not Position ?**
#
# * This is a tempting answer, but **exact** knowledge of location is impossible (since all sensor measurements are inherently imperfect).
# * Luckily we only need to **localize** a car to within a few cm.

# %% [markdown]
# **Speed**
# * A measurement of speed (like a measurement of anything) relies on imperfect equipment.
# * The job of the self driving car engineer is to make good **probabilistic estimates** from "bad" sensor data.

# %% [markdown]
# **Turning Motion**
# * Even this is unknowable! This uncertainty is the source of the "control noise" mentioned earlier and it's a constant nuisance to self driving car engineers (and roboticists in general).

# %% [markdown]
# # **2.2 Learning Objectives - Probability**

# %% [markdown]
# ## `QUESTION 1 OF 5`
#
# Which of the following are true statements about a fair coin?
#
#  * **Ans:** When flipping a coin multiple times, each flip is an **indenpendent event.**

# %% [markdown]
# ## `QUESTION 2 OF 5`

# %% [markdown]
# At a particular intersection, cars can either:
#
# 1. Turn left
#
# 2. Go straight
#
# 3. Turn right
#
# Cars tend to turn left with a probability of 0.4 and go straight with a probability of 0.25. What is the probability that a car turns right?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## `QUESTION 3 OF 5`
#
# **Ques:** You flip a fair coin 3 times. What's the probability that all three flips are heads?
#
# * **Ans:** Since each flip is an independent event, the probability of getting 3 heads is 0.5 * 0.5 * 0.5 (which is 0.125)

# %% [markdown]
# ### **Coin Even**

# %% [markdown]
# * Total number of Coin *Event* formula is :   $2^n$
# * Where  $n$ is number of coin flip.

# %% [markdown]
# **Coin Toss and event come**
#
# * P(only first 2 heads) = $p(H,H,T, ,...T)$
#
#  Now, each toss is independent.
#
#  So required probabilty = $p(H)p(H)*[p(T)^8]$
#
#  >   =  $(\frac{1}{2})^2(\frac{1}{2})^8$

# %% [markdown]
# ## `QUESTION 4 OF 5`
#
# **Ques:** You flip a fair coin two times. What's the probability that at least one flip is heads?
#
#   * **Ans:** $P(HT,HH, TH)= (\frac{3}{4})= 0.75$

# %% [markdown]
# ## `QUESTION 5 OF 5`
#
# **Ques:** You roll two six sided dice and then add the numbers together. What's the probability that the sum is equal to 7?
#
# * **Ans:** Total ways is (1,6),(2,5)(3,4) and it's reverse = 6 ways
#
#   $\therefore$ probability that the sum is equal to 7 = $\frac{6}{36}$ =
#    $\frac{1}{6}$

# %% [markdown]
# # **2.3 Probability**

# %% [markdown]
# * Probability is just the opposite of statistics.
# * There's a yin-yang relationship between both.

# %% [markdown]
# **Statistics**
# * In statistics we are given data and try to infer possible causes which relates to the data.

# %% [markdown]
# **Probability**
# *  We're given the description of the causes and we'd like to predict the data.

# %% [markdown]
# # **2.4 Loaded Coin**

# %% [markdown]
# * **A loaded coin is one that comes up with one of the two much more frequently than the other**.
#
#  **Ques:** What probability would I assess for this coin to come up heads?
#  * $P( Heads) = 1$
#  * $P( Tails) = 0$
#
#  > $P( Heads) + P( Tails) = 1$
#  >
#  >  $P( A)=  1 - P(A^c)$

# %% [markdown]
# ##  **Rules of Probabilty**
#  1. **Complementray probabilty :**
#
#    $P(A) = 1- P(A^c)$
#
#   * where $P(A^c)$ is Complementray probabilty of A. Means not A

# %% [markdown]
# # **2.5 Probability in Robotics**
#
# A self-driving car makes hundreds of calculations about probabilistic events every second, but the events are not as clean as a coin flip. For example:
#
#  1. What is the probability that this sensor measurement is accurate to within 5 centimeters? What about 1 centimeter?
#
#  2. What is the probability that some other vehicle will turn left at this intersection? Go straight? Turn right? What if they just sit there forever?
#
#  3. The radar and lidar measurements seem to disagree! What's the probability that the range finder somehow became detached from the roof?

# %% [markdown]
# # **2.6 Two Flips**
#
# 1. $P(H,H) = P(H)*P(H)= (\frac{1}{2} )\frac{1}{2}= 0.25$

# %% [markdown]
#  2. **Loaded coin**
#
#   * $P(H) = 0.6 $
#   * $P(T)= ?  $
#
#    > $P(T) = 0.4 $
#
#   * **Truth Table**
# \begin{array}{|c c|c|}
# Flip 1 & Flip 2 & P(A)\\ \hline
# H & H & 0.36\\
# H & T & 0.24\\
# T & H & 0.24\\
# T & T & 0.16\\ \hline
#  & Total & 1\\
# \end{array}
#
#   * $P(H,H)= 0.36$

# %% [markdown]
# 3. **Loaded coin 2**
#  * $P(H)= 1 $
#  * $P(T)= 0$
#
#  * **Truth Table**
# \begin{array}{|c c|c|}
# Flip 1 & Flip 2 & P(A)\\ \hline
# H & H & 1\\
# H & T & 0\\
# T & H & 0\\
# T & T & 0\\ \hline
#  & Total & 1\\
# \end{array}
#
#  * $P(H,H)= 1$

# %% [markdown]
# # **2.7 Two Cars 1-5**
#
# ![image.png](data:image/png;base64,...)
# ## **Question 1**
# For this question, assume the probabilities of left, straight, and right are all equal. That is:
#
#  $P(L) = \frac{1}{3}$
#  $P(S) = \frac{1}{3}$
#
#  $P(R) = \frac{1}{3}$
# ​
#
# > That's right. The probability is given by
#  *  $P(L,L) = P(L)*P(L)$
#  *  $P(L,L) = \frac{1}{3}* \frac{1}{3}$
#  *  $P(L,L) = \frac{1}{9}$

# %% [markdown]
# ## **Question 2**
#
# For this question assume that P(L) is known to be $\frac{1}{2}$. The other two quantities are unknown
#
#  * $P(L) = \frac{1}{2}$
# ​
#  * $P(S) = ?$
#  * $P(R) = ?$
#
#  > **Sol:**Not enough information to be determined.
#   * We do know that $P(S) <= 0.5P(S)<=0.5$

# %% [markdown]
# # **2.8 Managing Complexity**
#
# Roboticists will often use the term **state space** to describe the set of all possible outcomes for a **probabilistic event**.
#
# * For a coin the **state space** for a "flip" **event** can be written mathematically as:
#   $\{ \text{H}, \text{T} \}$
#
# * And for a car at an intersection the **state space** for a "turn" **event** can be written mathematically as:
#  $\{ \text{L}, \text{S}, \text{R} \}$

# %% [markdown]
# We can make these statements more broadly applicable:
#
#  1. When calculating the truth table for **2 events** which each have a **state space size of 2**, we need to make **4 calculations**.
#
#  2.  When calculating the truth table for **2 events** which each have a **state space size of 3**, we need to make **9 calculations**.
#
#   **Mathematical pattern expressed algebraically:**
#
#  3. When calculating the truth table for $N events$ which each have a **state space size of $x$**, we need to make $x^N$   calculations

# %% [markdown]
#  * $x^N$ gets very big fast as $x$ or $N$ get bigger.

# %% [markdown]
# *  **Note:** This **exponential complexity growth** can really slow down the performance of the code running inside of a self driving car.

# %% [markdown]
# # **2.9 One Of Three**
#
#  > **Ques :** P(Exactly one H in 3 flips) =$\frac{3}{8}$

# %% [markdown]
# ## **Even Roll**
#
#
# 1. One die event
#  * Event $N$=1
#  * state space size of $x$ =  6
#  * $x^N$ calculations= $6^1$ calculations
#
#  * P( Even Nummber on Die) = $\frac{3}{6}$

# %% [markdown]
# 2. Two die event
#  * Event $N$=2
#  * state space size of $x$ =  6
#  * $x^N$ calculations= $6^2$= 36 calculations
#
#  * P( Double(Identicle)) = $\frac{6}{36} = \frac{1}{36} $

# %% [markdown]
# # Summary
#
#  1. Probability of event = $P$
#  2. Probability of opposite event  = $1- P^c$
#  3. Probability of composite event  = $PPPP$ (Indepensent)
#
#  4.  When calculating the truth table for $N events$ which each have a **state space size of $x$**, we need to make $x^N$   calculations
